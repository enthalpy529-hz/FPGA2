# %%
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt

def convolution(k, data):
    n,m = np.shape(data)[0],np.shape(data)[1]
    img_new = []
    for i in range(n-3):
        line = []
        for j in range(m-3):
            a = data[i:i+3,j:j+3]
            line.append(np.sum(np.multiply(k, a)))
        img_new.append(line)
    return np.array(img_new)

def pic_show(pic):
    plt.imshow(pic, cmap='gray')
    plt.show()

img = cv2.imread('test.jpg')
img_hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
pic_show(img)

# %%
core = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
pic2 = convolution(core,img)
pic_show(pic2)

# %%
a = np.array([[1,2,3,1],[1,1,1,1]])
c = np.size(np.where(a==1)[0])
np.shape(a)
# Out:
# (2, 4)

# %%
h_value = []
for i in range(np.shape(img_hsv)[0]):
    for j in range(np.shape(img_hsv)[1]):
        h_value.append(img_hsv[i,j,0])

h_value = np.array(h_value)
import matplotlib.pyplot as plt
def hsv(value):
    color = np.zeros(360)
    for color_value in range(360):
        color[color_value] = np.size(np.where(value==color_value)[0])
    plt.plot(np.arange(360),color)
    plt.show()
hsv(h_value)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-8412ff2442fe> in <module>
#       2 core = np.ones([2,2])
#       3
# ----> 4 np.convolve(core,data)
#
# <__array_function__ internals> in convolve(*args, **kwargs)
#
# c:\Users\medphys3\anaconda3\envs\tf\lib\site-packages\numpy\core\numeric.py in convolve(a, v, mode)
#     848         raise ValueError('v cannot be empty')
#     849     mode = _mode_from_name(mode)
# --> 850     return multiarray.correlate(a, v[::-1], mode)
#     851
#     852
#
# ValueError: object too deep for desired array

# %%
def canny(pic):
    gray_pic = 
    gray_pic = 

    soble_x = np.array([[-1,0,1],[-2,0,2],[-1,0,1]])
    soble_y = np.array([[-1,-2,-1],[0,0,0],[1,2,1]])

# %%
def line(points,theta,threshold,num):
